# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
file = r'words.tst'
text=open(file,'r').read()
wc=WordCloud(stopwords = " ",background_color="white",max_words=100).generate(text)
plt.imshow(wc, interpolation="bilinear")
plt.show()

# %%
words = text.split()
words.__class__
# Out:
# list

# %%
words[:10]
# Out:
# ['The',
#  'Zen',
#  'of',
#  'Python,',
#  'by',
#  'Tim',
#  'Peters',
#  'Beautiful',
#  'is',
#  'better']

# %%
from collections import defaultdict

def getParams (f, count=10):
    
    linecount, wordcount = 0,0
    result = defaultdict(int)
    soubor = open(f, 'r')
    for line in soubor.readlines():
        #print("radek: {}".format(line.strip()))
        linecount += 1
        wordcount += len(line.strip().split())
        line = line.strip().split()
        for word in line:
            result[word]+=1
    soubor.close()
    top = {}
    #print("Soubor {} ma {} radku a {} slov".format(file, linecount, wordcount))
    #pojmenovany atribut key
    '''
    for word, freq in sorted(result.items(), key=lambda x:x[1], reverse=True)[:count]:
        top.update({word:freq})
    '''
    top = {word:freq for word, freq in sorted(result.items(), key=lambda x:x[1], reverse=True)[:count]}
    return (linecount, wordcount, top)

# %%
file = r'words.tst'
getParams(file, 15)
# Out:
# (21,
#  144,
#  {'is': 10,
#   'better': 8,
#   'than': 8,
#   'to': 5,
#   'the': 5,
#   'of': 3,
#   'Although': 3,
#   'be': 3,
#   'should': 2,
#   'never': 2,
#   'one': 2,
#   'way': 2,
#   'do': 2,
#   'may': 2,
#   'If': 2})

# %%
from collections import Counter
count = Counter(words)

# %%
count.most_common(15)
# Out:
# [('is', 10),
#  ('better', 8),
#  ('than', 8),
#  ('to', 5),
#  ('the', 5),
#  ('of', 3),
#  ('Although', 3),
#  ('be', 3),
#  ('should', 2),
#  ('never', 2),
#  ('one', 2),
#  ('way', 2),
#  ('do', 2),
#  ('may', 2),
#  ('If', 2)]

# %%
count.items()
# Out:
# dict_items([('The', 1), ('Zen', 1), ('of', 3), ('Python,', 1), ('by', 1), ('Tim', 1), ('Peters', 1), ('Beautiful', 1), ('is', 10), ('better', 8), ('than', 8), ('ugly.', 1), ('Explicit', 1), ('implicit.', 1), ('Simple', 1), ('complex.', 1), ('Complex', 1), ('complicated.', 1), ('Flat', 1), ('nested.', 1), ('Sparse', 1), ('dense.', 1), ('Readability', 1), ('counts.', 1), ('Special', 1), ('cases', 1), ("aren't", 1), ('special', 1), ('enough', 1), ('to', 5), ('break', 1), ('the', 5), ('rules.', 1), ('Although', 3), ('practicality', 1), ('beats', 1), ('purity.', 1), ('Errors', 1), ('should', 2), ('never', 2), ('pass', 1), ('silently.', 1), ('Unless', 1), ('explicitly', 1), ('silenced.', 1), ('In', 1), ('face', 1), ('ambiguity,', 1), ('refuse', 1), ('temptation', 1), ('guess.', 1), ('There', 1), ('be', 3), ('one--', 1), ('and', 1), ('preferably', 1), ('only', 1), ('one', 2), ('--obvious', 1), ('way', 2), ('do', 2), ('it.', 1), ('that', 1), ('may', 2), ('not', 1), ('obvious', 1), ('at', 1), ('first', 1), ('unless', 1), ("you're", 1), ('Dutch.', 1), ('Now', 1), ('never.', 1), ('often', 1), ('*right*', 1), ('now.', 1), ('If', 2), ('implementation', 2), ('hard', 1), ('explain,', 2), ("it's", 1), ('a', 2), ('bad', 1), ('idea.', 2), ('easy', 1), ('it', 1), ('good', 1), ('Namespaces', 1), ('are', 1), ('honking', 1), ('great', 1), ('idea', 1), ('--', 1), ("let's", 1), ('more', 1), ('those!', 1)])

# %%
xs =[]
ys = []
for x, y in count.items():
    #print(x,y)
    xs.append(x)
    ys.append(y)

# %%
xs = count.keys()
ys = count.values()

# %%
a = zip(xs,ys)
print(sorted(list(a), reverse=True, key = lambda x:x[1]))
# Out:
# [('is', 10), ('better', 8), ('than', 8), ('to', 5), ('the', 5), ('of', 3), ('Although', 3), ('be', 3), ('should', 2), ('never', 2), ('one', 2), ('way', 2), ('do', 2), ('may', 2), ('If', 2), ('implementation', 2), ('explain,', 2), ('a', 2), ('idea.', 2), ('The', 1), ('Zen', 1), ('Python,', 1), ('by', 1), ('Tim', 1), ('Peters', 1), ('Beautiful', 1), ('ugly.', 1), ('Explicit', 1), ('implicit.', 1), ('Simple', 1), ('complex.', 1), ('Complex', 1), ('complicated.', 1), ('Flat', 1), ('nested.', 1), ('Sparse', 1), ('dense.', 1), ('Readability', 1), ('counts.', 1), ('Special', 1), ('cases', 1), ("aren't", 1), ('special', 1), ('enough', 1), ('break', 1), ('rules.', 1), ('practicality', 1), ('beats', 1), ('purity.', 1), ('Errors', 1), ('pass', 1), ('silently.', 1), ('Unless', 1), ('explicitly', 1), ('silenced.', 1), ('In', 1), ('face', 1), ('ambiguity,', 1), ('refuse', 1), ('temptation', 1), ('guess.', 1), ('There', 1), ('one--', 1), ('and', 1), ('preferably', 1), ('only', 1), ('--obvious', 1), ('it.', 1), ('that', 1), ('not', 1), ('obvious', 1), ('at', 1), ('first', 1), ('unless', 1), ("you're", 1), ('Dutch.', 1), ('Now', 1), ('never.', 1), ('often', 1), ('*right*', 1), ('now.', 1), ('hard', 1), ("it's", 1), ('bad', 1), ('easy', 1), ('it', 1), ('good', 1), ('Namespaces', 1), ('are', 1), ('honking', 1), ('great', 1), ('idea', 1), ('--', 1), ("let's", 1), ('more', 1), ('those!', 1)]
